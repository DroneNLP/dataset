# %%
import os

print(os.path.abspath(os.curdir))
# Out:
# d:\Data Kuliah\Semester 9\Data in Brief\dataset\notebooks

# %%
import os
os.chdir("..")

# %%
print(os.path.abspath(os.curdir))
# Out:
# d:\Data Kuliah\Semester 9\Data in Brief\dataset

# %% [markdown]
# ### Binary dataset class distribution

# %%
import pandas as pd

binary_train = pd.read_csv('binary/train.csv')
binary_test = pd.read_csv('binary/test.csv')

# %%
binary_train['labels'].value_counts()
# Out:
# labels
# Problem    865
# Normal     533
# Name: count, dtype: int64

# %%
binary_test['labels'].value_counts()
# Out:
# labels
# Problem    279
# Normal     176
# Name: count, dtype: int64

# %% [markdown]
# ### Multiclass Severity - Unfiltered

# %%
unfiltered_train = pd.read_csv('severity/duplicate/unfiltered_train.csv')
unfiltered_test = pd.read_csv('severity/duplicate/unfiltered_test.csv')

# %%
unfiltered_train['label'].value_counts()
# Out:
# label
# Normal    696
# Medium    632
# Low       433
# High       32
# Name: count, dtype: int64

# %%
unfiltered_test['label'].value_counts()
# Out:
# label
# Normal    174
# Medium    159
# Low       108
# High        8
# Name: count, dtype: int64

# %% [markdown]
# ### Multiclass Severity - Filtered

# %%
filtered_train = pd.read_csv('severity/unique/filtered_train.csv')
filtered_test = pd.read_csv('severity/unique/filtered_test.csv')

# %%
filtered_train['label'].value_counts()
# Out:
# label
# Low       173
# Normal    161
# Medium    104
# High       30
# Name: count, dtype: int64

# %%
filtered_test['label'].value_counts()
# Out:
# label
# Low       43
# Normal    40
# Medium    26
# High       8
# Name: count, dtype: int64
