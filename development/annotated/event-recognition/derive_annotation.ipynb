# %%
import json


with open('annotations.json', 'r') as file:
    data = json.load(file)

# %%
annotations = data['annotations']
for text, label in annotations:
    print(f'text: {text}')
    print(f'label: {label}')
# Out:
# text: Setting new Return-To-Home altitude to nnn (nnn).
# label: {'entities': [[0, 48, 'EVENT']]}
# text: Data Recorder File Index is nnn.
# label: {'entities': [[0, 31, 'CONTEXT']]}
# text: Setting new Maximum Flight Altitude to nnn (nnn).
# label: {'entities': [[0, 48, 'EVENT']]}
# text: Gimbal nnn pitch axis endpoint reached.
# label: {'entities': [[0, 38, 'EVENT']]}
# text: Your aircraft is flying in an Altitude Zone (nnn). Please fly with caution.
# label: {'entities': [[0, 49, 'EVENT'], [51, 74, 'MITIGATION']]}
# text: Aircraft not in flight. Vision systems and obstacle avoidance disabled (Code: 180059).
# label: {'entities': [[0, 23, 'EVENT'], [24, 70, 'EVENT'], [72, 84, 'CONTEXT']]}
# text: The remaining battery is only enough for RTH. Return home now.
# label: {'entities': [[0, 45, 'EVENT'], [46, 61, 'MITIGATION']]}
# text: Reaching maximum altitude.
# label: {'entities': [[0, 25, 'EVENT']]}
# text: Gimbal Recenter.
# label: {'entities': [[0, 15, 'EVENT']]}
# ...

# %%
annotations
# Out:
# [['Setting new Return-To-Home altitude to nnn (nnn).\r',
#   {'entities': [[0, 48, 'EVENT']]}],
#  ['Data Recorder File Index is nnn.\r', {'entities': [[0, 31, 'CONTEXT']]}],
#  ['Setting new Maximum Flight Altitude to nnn (nnn).\r',
#   {'entities': [[0, 48, 'EVENT']]}],
#  ['Gimbal nnn pitch axis endpoint reached.\r',
#   {'entities': [[0, 38, 'EVENT']]}],
#  ['Your aircraft is flying in an Altitude Zone (nnn). Please fly with caution.\r',
#   {'entities': [[0, 49, 'EVENT'], [51, 74, 'MITIGATION']]}],
#  ['Aircraft not in flight. Vision systems and obstacle avoidance disabled (Code: 180059).\r',
#   {'entities': [[0, 23, 'EVENT'], [24, 70, 'EVENT'], [72, 84, 'CONTEXT']]}],
#  ['The remaining battery is only enough for RTH. Return home now.\r',
#   {'entities': [[0, 45, 'EVENT'], [46, 61, 'MITIGATION']]}],
#  ['Reaching maximum altitude.\r', {'entities': [[0, 25, 'EVENT']]}],
#  ['Gimbal Recenter.\r', {'entities': [[0, 15, 'EVENT']]}],
# ...
